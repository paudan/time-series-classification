# %%
import os
import pickle
import pandas as pd

pd.options.display.max_rows = 200

# %% [markdown]
# ## tsfresh features based classifier

# %%
with open(os.path.join("results", "tsfresh_results.pkl"), "rb") as f:
    data = pickle.load(f)
data
# Out:
# classifier                     RandomForestClassifier           \
# metric                                       Accuracy F1-Score
# ACSF1                                             NaN      NaN
# Adiac                                             NaN      NaN
# AllGestureWiimoteX                                NaN      NaN
# AllGestureWiimoteY                                NaN      NaN
# AllGestureWiimoteZ                                NaN      NaN
# ArrowHead                                         NaN      NaN
# Beef                                              NaN      NaN
# BeetleFly                                         NaN      NaN
# BirdChicken                                       NaN      NaN
# BME                                               NaN      NaN
# Car                                               NaN      NaN
# CBF                                               NaN      NaN
# Chinatown                                         NaN      NaN
# ChlorineConcentration                             NaN      NaN
# CinCECGTorso                                      NaN      NaN
# Coffee                                            NaN      NaN
# Computers                                         NaN      NaN
# CricketX                                          NaN      NaN
# CricketY                                          NaN      NaN
# CricketZ                                          NaN      NaN
# Crop                                              NaN      NaN
# DiatomSizeReduction                               NaN      NaN
# DistalPhalanxOutlineAgeGroup                      NaN      NaN
# DistalPhalanxOutlineCorrect                       NaN      NaN
# DistalPhalanxTW                                   NaN      NaN
# DodgerLoopDay                                     NaN      NaN
# DodgerLoopGame                                    NaN      NaN
# DodgerLoopWeekend                                 NaN      NaN
# Earthquakes                                       NaN      NaN
# ECG200                                            NaN      NaN
# ECG5000                                           NaN      NaN
# ECGFiveDays                                       NaN      NaN
# ElectricDevices                                   NaN      NaN
# EOGHorizontalSignal                               NaN      NaN
# EOGVerticalSignal                                 NaN      NaN
# EthanolLevel                                      NaN      NaN
# FaceAll                                           NaN      NaN
# FaceFour                                          NaN      NaN
# FacesUCR                                          NaN      NaN
# FiftyWords                                        NaN      NaN
# Fish                                              NaN      NaN
# FordA                                             NaN      NaN
# FordB                                             NaN      NaN
# FreezerRegularTrain                               NaN      NaN
# FreezerSmallTrain                                 NaN      NaN
# Fungi                                             NaN      NaN
# GestureMidAirD1                                   NaN      NaN
# GestureMidAirD2                                   NaN      NaN
# GestureMidAirD3                                   NaN      NaN
# GesturePebbleZ1                                   NaN      NaN
# GesturePebbleZ2                                   NaN      NaN
# GunPoint                                          NaN      NaN
# GunPointAgeSpan                                   NaN      NaN
# GunPointMaleVersusFemale                          NaN      NaN
# GunPointOldVersusYoung                            NaN      NaN
# Ham                                               NaN      NaN
# HandOutlines                                      NaN      NaN
# Haptics                                           NaN      NaN
# Herring                                           NaN      NaN
# HouseTwenty                                       NaN      NaN
# InlineSkate                                       NaN      NaN
# InsectEPGRegularTrain                             NaN      NaN
# InsectEPGSmallTrain                               NaN      NaN
# InsectWingbeatSound                               NaN      NaN
# ItalyPowerDemand                                  NaN      NaN
# LargeKitchenAppliances                            NaN      NaN
# Lightning2                                        NaN      NaN
# Lightning7                                        NaN      NaN
# Mallat                                            NaN      NaN
# Meat                                              NaN      NaN
# MedicalImages                                     NaN      NaN
# MelbournePedestrian                               NaN      NaN
# MiddlePhalanxOutlineAgeGroup                      NaN      NaN
# MiddlePhalanxOutlineCorrect                       NaN      NaN
# MiddlePhalanxTW                                   NaN      NaN
# MixedShapesRegularTrain                           NaN      NaN
# MixedShapesSmallTrain                             NaN      NaN
# MoteStrain                                        NaN      NaN
# NonInvasiveFetalECGThorax1                        NaN      NaN
# NonInvasiveFetalECGThorax2                        NaN      NaN
# OliveOil                                          NaN      NaN
# OSULeaf                                           NaN      NaN
# PhalangesOutlinesCorrect                          NaN      NaN
# Phoneme                                           NaN      NaN
# PickupGestureWiimoteZ                             NaN      NaN
# PigAirwayPressure                                 NaN      NaN
# PigArtPressure                                    NaN      NaN
# PigCVP                                            NaN      NaN
# PLAID                                             NaN      NaN
# Plane                                             NaN      NaN
# PowerCons                                         NaN      NaN
# ProximalPhalanxOutlineAgeGroup                    NaN      NaN
# ProximalPhalanxOutlineCorrect                     NaN      NaN
# ProximalPhalanxTW                                 NaN      NaN
# RefrigerationDevices                              NaN      NaN
# Rock                                              NaN      NaN
# ScreenType                                        NaN      NaN
# SemgHandGenderCh2                                 NaN      NaN
# SemgHandMovementCh2                               NaN      NaN
# SemgHandSubjectCh2                                NaN      NaN
# ShakeGestureWiimoteZ                              NaN      NaN
# ShapeletSim                                       NaN      NaN
# ShapesAll                                         NaN      NaN
# SmallKitchenAppliances                            NaN      NaN
# SmoothSubspace                                    NaN      NaN
# SonyAIBORobotSurface1                             NaN      NaN
# SonyAIBORobotSurface2                             NaN      NaN
# StarLightCurves                                   NaN      NaN
# Strawberry                                        NaN      NaN
# SwedishLeaf                                       NaN      NaN
# Symbols                                           NaN      NaN
# SyntheticControl                                  NaN      NaN
# ToeSegmentation1                                  NaN      NaN
# ToeSegmentation2                                  NaN      NaN
# Trace                                             NaN      NaN
# TwoLeadECG                                        NaN      NaN
# TwoPatterns                                       NaN      NaN
# UMD                                               NaN      NaN
# UWaveGestureLibraryAll                            NaN      NaN
# UWaveGestureLibraryX                              NaN      NaN
# UWaveGestureLibraryY                              NaN      NaN
# UWaveGestureLibraryZ                              NaN      NaN
# Wafer                                             NaN      NaN
# Wine                                              NaN      NaN
# WordSynonyms                                      NaN      NaN
# Worms                                             NaN      NaN
# WormsTwoClass                                     NaN      NaN
# Yoga                                              NaN      NaN
#
# classifier                     ExtraTreesClassifier          XGBClassifier  \
# metric                                     Accuracy F1-Score      Accuracy
# ACSF1                                           NaN      NaN           NaN
# Adiac                                           NaN      NaN           NaN
# AllGestureWiimoteX                              NaN      NaN           NaN
# AllGestureWiimoteY                              NaN      NaN           NaN
# AllGestureWiimoteZ                              NaN      NaN           NaN
# ArrowHead                                       NaN      NaN           NaN
# Beef                                            NaN      NaN           NaN
# BeetleFly                                       NaN      NaN           NaN
# BirdChicken                                     NaN      NaN           NaN
# BME                                             NaN      NaN           NaN
# Car                                             NaN      NaN           NaN
# CBF                                             NaN      NaN           NaN
# Chinatown                                       NaN      NaN           NaN
# ChlorineConcentration                           NaN      NaN           NaN
# CinCECGTorso                                    NaN      NaN           NaN
# Coffee                                          NaN      NaN           NaN
# Computers                                       NaN      NaN           NaN
# CricketX                                        NaN      NaN           NaN
# CricketY                                        NaN      NaN           NaN
# CricketZ                                        NaN      NaN           NaN
# Crop                                            NaN      NaN           NaN
# DiatomSizeReduction                             NaN      NaN           NaN
# DistalPhalanxOutlineAgeGroup                    NaN      NaN           NaN
# DistalPhalanxOutlineCorrect                     NaN      NaN           NaN
# DistalPhalanxTW                                 NaN      NaN           NaN
# DodgerLoopDay                                   NaN      NaN           NaN
# DodgerLoopGame                                  NaN      NaN           NaN
# DodgerLoopWeekend                               NaN      NaN           NaN
# Earthquakes                                     NaN      NaN           NaN
# ECG200                                          NaN      NaN           NaN
# ECG5000                                         NaN      NaN           NaN
# ECGFiveDays                                     NaN      NaN           NaN
# ElectricDevices                                 NaN      NaN           NaN
# EOGHorizontalSignal                             NaN      NaN           NaN
# EOGVerticalSignal                               NaN      NaN           NaN
# EthanolLevel                                    NaN      NaN           NaN
# FaceAll                                         NaN      NaN           NaN
# FaceFour                                        NaN      NaN           NaN
# FacesUCR                                        NaN      NaN           NaN
# FiftyWords                                      NaN      NaN           NaN
# Fish                                            NaN      NaN           NaN
# FordA                                           NaN      NaN           NaN
# FordB                                           NaN      NaN           NaN
# FreezerRegularTrain                             NaN      NaN           NaN
# FreezerSmallTrain                               NaN      NaN           NaN
# Fungi                                           NaN      NaN           NaN
# GestureMidAirD1                                 NaN      NaN           NaN
# GestureMidAirD2                                 NaN      NaN           NaN
# GestureMidAirD3                                 NaN      NaN           NaN
# GesturePebbleZ1                                 NaN      NaN           NaN
# GesturePebbleZ2                                 NaN      NaN           NaN
# GunPoint                                        NaN      NaN           NaN
# GunPointAgeSpan                                 NaN      NaN           NaN
# GunPointMaleVersusFemale                        NaN      NaN           NaN
# GunPointOldVersusYoung                          NaN      NaN           NaN
# Ham                                             NaN      NaN           NaN
# HandOutlines                                    NaN      NaN           NaN
# Haptics                                         NaN      NaN           NaN
# Herring                                         NaN      NaN           NaN
# HouseTwenty                                     NaN      NaN           NaN
# InlineSkate                                     NaN      NaN           NaN
# InsectEPGRegularTrain                           NaN      NaN           NaN
# InsectEPGSmallTrain                             NaN      NaN           NaN
# InsectWingbeatSound                             NaN      NaN           NaN
# ItalyPowerDemand                                NaN      NaN           NaN
# LargeKitchenAppliances                          NaN      NaN           NaN
# Lightning2                                      NaN      NaN           NaN
# Lightning7                                      NaN      NaN           NaN
# Mallat                                          NaN      NaN           NaN
# Meat                                            NaN      NaN           NaN
# MedicalImages                                   NaN      NaN           NaN
# MelbournePedestrian                             NaN      NaN           NaN
# MiddlePhalanxOutlineAgeGroup                    NaN      NaN           NaN
# MiddlePhalanxOutlineCorrect                     NaN      NaN           NaN
# MiddlePhalanxTW                                 NaN      NaN           NaN
# MixedShapesRegularTrain                         NaN      NaN           NaN
# MixedShapesSmallTrain                           NaN      NaN           NaN
# MoteStrain                                      NaN      NaN           NaN
# NonInvasiveFetalECGThorax1                      NaN      NaN           NaN
# NonInvasiveFetalECGThorax2                      NaN      NaN           NaN
# OliveOil                                        NaN      NaN           NaN
# OSULeaf                                         NaN      NaN           NaN
# PhalangesOutlinesCorrect                        NaN      NaN           NaN
# Phoneme                                         NaN      NaN           NaN
# PickupGestureWiimoteZ                           NaN      NaN           NaN
# PigAirwayPressure                               NaN      NaN           NaN
# PigArtPressure                                  NaN      NaN           NaN
# PigCVP                                          NaN      NaN           NaN
# PLAID                                           NaN      NaN           NaN
# Plane                                           NaN      NaN           NaN
# PowerCons                                       NaN      NaN           NaN
# ProximalPhalanxOutlineAgeGroup                  NaN      NaN           NaN
# ProximalPhalanxOutlineCorrect                   NaN      NaN           NaN
# ProximalPhalanxTW                               NaN      NaN           NaN
# RefrigerationDevices                            NaN      NaN           NaN
# Rock                                            NaN      NaN           NaN
# ScreenType                                      NaN      NaN           NaN
# SemgHandGenderCh2                               NaN      NaN           NaN
# SemgHandMovementCh2                             NaN      NaN           NaN
# SemgHandSubjectCh2                              NaN      NaN           NaN
# ShakeGestureWiimoteZ                            NaN      NaN           NaN
# ShapeletSim                                     NaN      NaN           NaN
# ShapesAll                                       NaN      NaN           NaN
# SmallKitchenAppliances                          NaN      NaN           NaN
# SmoothSubspace                                  NaN      NaN           NaN
# SonyAIBORobotSurface1                           NaN      NaN           NaN
# SonyAIBORobotSurface2                           NaN      NaN           NaN
# StarLightCurves                                 NaN      NaN           NaN
# Strawberry                                      NaN      NaN           NaN
# SwedishLeaf                                     NaN      NaN           NaN
# Symbols                                         NaN      NaN           NaN
# SyntheticControl                                NaN      NaN           NaN
# ToeSegmentation1                                NaN      NaN           NaN
# ToeSegmentation2                                NaN      NaN           NaN
# Trace                                           NaN      NaN           NaN
# TwoLeadECG                                      NaN      NaN           NaN
# TwoPatterns                                     NaN      NaN           NaN
# UMD                                             NaN      NaN           NaN
# UWaveGestureLibraryAll                          NaN      NaN           NaN
# UWaveGestureLibraryX                            NaN      NaN           NaN
# UWaveGestureLibraryY                            NaN      NaN           NaN
# UWaveGestureLibraryZ                            NaN      NaN           NaN
# Wafer                                           NaN      NaN           NaN
# Wine                                            NaN      NaN           NaN
# WordSynonyms                                    NaN      NaN           NaN
# Worms                                           NaN      NaN           NaN
# WormsTwoClass                                   NaN      NaN           NaN
# Yoga                                            NaN      NaN           NaN
#
# classifier
# metric                         F1-Score
# ACSF1                               NaN
# Adiac                               NaN
# AllGestureWiimoteX                  NaN
# AllGestureWiimoteY                  NaN
# AllGestureWiimoteZ                  NaN
# ArrowHead                           NaN
# Beef                                NaN
# BeetleFly                           NaN
# BirdChicken                         NaN
# BME                                 NaN
# Car                                 NaN
# CBF                                 NaN
# Chinatown                           NaN
# ChlorineConcentration               NaN
# CinCECGTorso                        NaN
# Coffee                              NaN
# Computers                           NaN
# CricketX                            NaN
# CricketY                            NaN
# CricketZ                            NaN
# Crop                                NaN
# DiatomSizeReduction                 NaN
# DistalPhalanxOutlineAgeGroup        NaN
# DistalPhalanxOutlineCorrect         NaN
# DistalPhalanxTW                     NaN
# DodgerLoopDay                       NaN
# DodgerLoopGame                      NaN
# DodgerLoopWeekend                   NaN
# Earthquakes                         NaN
# ECG200                              NaN
# ECG5000                             NaN
# ECGFiveDays                         NaN
# ElectricDevices                     NaN
# EOGHorizontalSignal                 NaN
# EOGVerticalSignal                   NaN
# EthanolLevel                        NaN
# FaceAll                             NaN
# FaceFour                            NaN
# FacesUCR                            NaN
# FiftyWords                          NaN
# Fish                                NaN
# FordA                               NaN
# FordB                               NaN
# FreezerRegularTrain                 NaN
# FreezerSmallTrain                   NaN
# Fungi                               NaN
# GestureMidAirD1                     NaN
# GestureMidAirD2                     NaN
# GestureMidAirD3                     NaN
# GesturePebbleZ1                     NaN
# GesturePebbleZ2                     NaN
# GunPoint                            NaN
# GunPointAgeSpan                     NaN
# GunPointMaleVersusFemale            NaN
# GunPointOldVersusYoung              NaN
# Ham                                 NaN
# HandOutlines                        NaN
# Haptics                             NaN
# Herring                             NaN
# HouseTwenty                         NaN
# InlineSkate                         NaN
# InsectEPGRegularTrain               NaN
# InsectEPGSmallTrain                 NaN
# InsectWingbeatSound                 NaN
# ItalyPowerDemand                    NaN
# LargeKitchenAppliances              NaN
# Lightning2                          NaN
# Lightning7                          NaN
# Mallat                              NaN
# Meat                                NaN
# MedicalImages                       NaN
# MelbournePedestrian                 NaN
# MiddlePhalanxOutlineAgeGroup        NaN
# MiddlePhalanxOutlineCorrect         NaN
# MiddlePhalanxTW                     NaN
# MixedShapesRegularTrain             NaN
# MixedShapesSmallTrain               NaN
# MoteStrain                          NaN
# NonInvasiveFetalECGThorax1          NaN
# NonInvasiveFetalECGThorax2          NaN
# OliveOil                            NaN
# OSULeaf                             NaN
# PhalangesOutlinesCorrect            NaN
# Phoneme                             NaN
# PickupGestureWiimoteZ               NaN
# PigAirwayPressure                   NaN
# PigArtPressure                      NaN
# PigCVP                              NaN
# PLAID                               NaN
# Plane                               NaN
# PowerCons                           NaN
# ProximalPhalanxOutlineAgeGroup      NaN
# ProximalPhalanxOutlineCorrect       NaN
# ProximalPhalanxTW                   NaN
# RefrigerationDevices                NaN
# Rock                                NaN
# ScreenType                          NaN
# SemgHandGenderCh2                   NaN
# SemgHandMovementCh2                 NaN
# SemgHandSubjectCh2                  NaN
# ShakeGestureWiimoteZ                NaN
# ShapeletSim                         NaN
# ShapesAll                           NaN
# SmallKitchenAppliances              NaN
# SmoothSubspace                      NaN
# SonyAIBORobotSurface1               NaN
# SonyAIBORobotSurface2               NaN
# StarLightCurves                     NaN
# Strawberry                          NaN
# SwedishLeaf                         NaN
# Symbols                             NaN
# SyntheticControl                    NaN
# ToeSegmentation1                    NaN
# ToeSegmentation2                    NaN
# Trace                               NaN
# TwoLeadECG                          NaN
# TwoPatterns                         NaN
# UMD                                 NaN
# UWaveGestureLibraryAll              NaN
# UWaveGestureLibraryX                NaN
# UWaveGestureLibraryY                NaN
# UWaveGestureLibraryZ                NaN
# Wafer                               NaN
# Wine                                NaN
# WordSynonyms                        NaN
# Worms                               NaN
# WormsTwoClass                       NaN
# Yoga                                NaN

# %% [markdown]
# ## Catch22 features based classifier

# %%
with open(os.path.join("results", "catch22_results.pkl"), "rb") as f:
    data = pickle.load(f)
data
# Out:
# classifier                     RandomForestClassifier           \
# metric                                       Accuracy F1-Score
# ACSF1                                             NaN      NaN
# Adiac                                             NaN      NaN
# ArrowHead                                         NaN      NaN
# Beef                                              NaN      NaN
# BeetleFly                                         NaN      NaN
# BirdChicken                                       NaN      NaN
# BME                                               NaN      NaN
# Car                                               NaN      NaN
# CBF                                               NaN      NaN
# Chinatown                                         NaN      NaN
# ChlorineConcentration                             NaN      NaN
# CinCECGTorso                                      NaN      NaN
# Coffee                                            NaN      NaN
# Computers                                         NaN      NaN
# CricketX                                          NaN      NaN
# CricketY                                          NaN      NaN
# CricketZ                                          NaN      NaN
# Crop                                              NaN      NaN
# DiatomSizeReduction                               NaN      NaN
# DistalPhalanxOutlineAgeGroup                      NaN      NaN
# DistalPhalanxOutlineCorrect                       NaN      NaN
# DistalPhalanxTW                                   NaN      NaN
# DodgerLoopDay                                     NaN      NaN
# DodgerLoopGame                                    NaN      NaN
# DodgerLoopWeekend                                 NaN      NaN
# Earthquakes                                       NaN      NaN
# ECG200                                            NaN      NaN
# ECG5000                                           NaN      NaN
# ECGFiveDays                                       NaN      NaN
# ElectricDevices                                   NaN      NaN
# EOGHorizontalSignal                               NaN      NaN
# EOGVerticalSignal                                 NaN      NaN
# EthanolLevel                                      NaN      NaN
# FaceAll                                           NaN      NaN
# FaceFour                                          NaN      NaN
# FacesUCR                                          NaN      NaN
# FiftyWords                                        NaN      NaN
# Fish                                              NaN      NaN
# FordA                                             NaN      NaN
# FordB                                             NaN      NaN
# FreezerRegularTrain                               NaN      NaN
# FreezerSmallTrain                                 NaN      NaN
# Fungi                                             NaN      NaN
# GestureMidAirD1                                   NaN      NaN
# GestureMidAirD2                                   NaN      NaN
# GestureMidAirD3                                   NaN      NaN
# GesturePebbleZ1                                   NaN      NaN
# GesturePebbleZ2                                   NaN      NaN
# GunPoint                                          NaN      NaN
# GunPointAgeSpan                                   NaN      NaN
# GunPointMaleVersusFemale                          NaN      NaN
# GunPointOldVersusYoung                            NaN      NaN
# Ham                                               NaN      NaN
# HandOutlines                                      NaN      NaN
# Haptics                                           NaN      NaN
# Herring                                           NaN      NaN
# HouseTwenty                                       NaN      NaN
# InlineSkate                                       NaN      NaN
# InsectEPGRegularTrain                             NaN      NaN
# InsectEPGSmallTrain                               NaN      NaN
# InsectWingbeatSound                               NaN      NaN
# ItalyPowerDemand                                  NaN      NaN
# LargeKitchenAppliances                            NaN      NaN
# Lightning2                                        NaN      NaN
# Lightning7                                        NaN      NaN
# Mallat                                            NaN      NaN
# Meat                                              NaN      NaN
# MedicalImages                                     NaN      NaN
# MelbournePedestrian                               NaN      NaN
# MiddlePhalanxOutlineAgeGroup                      NaN      NaN
# MiddlePhalanxOutlineCorrect                       NaN      NaN
# MiddlePhalanxTW                                   NaN      NaN
# MixedShapesRegularTrain                           NaN      NaN
# MixedShapesSmallTrain                             NaN      NaN
# MoteStrain                                        NaN      NaN
# NonInvasiveFetalECGThorax1                        NaN      NaN
# NonInvasiveFetalECGThorax2                        NaN      NaN
# OliveOil                                          NaN      NaN
# OSULeaf                                           NaN      NaN
# PhalangesOutlinesCorrect                          NaN      NaN
# Phoneme                                           NaN      NaN
# PickupGestureWiimoteZ                             NaN      NaN
# PigAirwayPressure                                 NaN      NaN
# PigArtPressure                                    NaN      NaN
# PigCVP                                            NaN      NaN
# PLAID                                             NaN      NaN
# Plane                                             NaN      NaN
# PowerCons                                         NaN      NaN
# ProximalPhalanxOutlineAgeGroup                    NaN      NaN
# ProximalPhalanxOutlineCorrect                     NaN      NaN
# ProximalPhalanxTW                                 NaN      NaN
# RefrigerationDevices                              NaN      NaN
# Rock                                              NaN      NaN
# ScreenType                                        NaN      NaN
# SemgHandGenderCh2                                 NaN      NaN
# SemgHandMovementCh2                               NaN      NaN
# SemgHandSubjectCh2                                NaN      NaN
# ShakeGestureWiimoteZ                              NaN      NaN
# ShapeletSim                                       NaN      NaN
# ShapesAll                                         NaN      NaN
# SmallKitchenAppliances                            NaN      NaN
# SmoothSubspace                                    NaN      NaN
# SonyAIBORobotSurface1                             NaN      NaN
# SonyAIBORobotSurface2                             NaN      NaN
# StarLightCurves                                   NaN      NaN
# Strawberry                                        NaN      NaN
# SwedishLeaf                                       NaN      NaN
# Symbols                                           NaN      NaN
# SyntheticControl                                  NaN      NaN
# ToeSegmentation1                                  NaN      NaN
# ToeSegmentation2                                  NaN      NaN
# Trace                                             NaN      NaN
# TwoLeadECG                                        NaN      NaN
# TwoPatterns                                       NaN      NaN
# UMD                                               NaN      NaN
# UWaveGestureLibraryAll                            NaN      NaN
# UWaveGestureLibraryX                              NaN      NaN
# UWaveGestureLibraryY                              NaN      NaN
# UWaveGestureLibraryZ                              NaN      NaN
# Wafer                                             NaN      NaN
# Wine                                              NaN      NaN
# WordSynonyms                                      NaN      NaN
# Worms                                             NaN      NaN
# WormsTwoClass                                     NaN      NaN
# Yoga                                              NaN      NaN
#
# classifier                     ExtraTreesClassifier          XGBClassifier  \
# metric                                     Accuracy F1-Score      Accuracy
# ACSF1                                           NaN      NaN           NaN
# Adiac                                           NaN      NaN           NaN
# ArrowHead                                       NaN      NaN           NaN
# Beef                                            NaN      NaN           NaN
# BeetleFly                                       NaN      NaN           NaN
# BirdChicken                                     NaN      NaN           NaN
# BME                                             NaN      NaN           NaN
# Car                                             NaN      NaN           NaN
# CBF                                             NaN      NaN           NaN
# Chinatown                                       NaN      NaN           NaN
# ChlorineConcentration                           NaN      NaN           NaN
# CinCECGTorso                                    NaN      NaN           NaN
# Coffee                                          NaN      NaN           NaN
# Computers                                       NaN      NaN           NaN
# CricketX                                        NaN      NaN           NaN
# CricketY                                        NaN      NaN           NaN
# CricketZ                                        NaN      NaN           NaN
# Crop                                            NaN      NaN           NaN
# DiatomSizeReduction                             NaN      NaN           NaN
# DistalPhalanxOutlineAgeGroup                    NaN      NaN           NaN
# DistalPhalanxOutlineCorrect                     NaN      NaN           NaN
# DistalPhalanxTW                                 NaN      NaN           NaN
# DodgerLoopDay                                   NaN      NaN           NaN
# DodgerLoopGame                                  NaN      NaN           NaN
# DodgerLoopWeekend                               NaN      NaN           NaN
# Earthquakes                                     NaN      NaN           NaN
# ECG200                                          NaN      NaN           NaN
# ECG5000                                         NaN      NaN           NaN
# ECGFiveDays                                     NaN      NaN           NaN
# ElectricDevices                                 NaN      NaN           NaN
# EOGHorizontalSignal                             NaN      NaN           NaN
# EOGVerticalSignal                               NaN      NaN           NaN
# EthanolLevel                                    NaN      NaN           NaN
# FaceAll                                         NaN      NaN           NaN
# FaceFour                                        NaN      NaN           NaN
# FacesUCR                                        NaN      NaN           NaN
# FiftyWords                                      NaN      NaN           NaN
# Fish                                            NaN      NaN           NaN
# FordA                                           NaN      NaN           NaN
# FordB                                           NaN      NaN           NaN
# FreezerRegularTrain                             NaN      NaN           NaN
# FreezerSmallTrain                               NaN      NaN           NaN
# Fungi                                           NaN      NaN           NaN
# GestureMidAirD1                                 NaN      NaN           NaN
# GestureMidAirD2                                 NaN      NaN           NaN
# GestureMidAirD3                                 NaN      NaN           NaN
# GesturePebbleZ1                                 NaN      NaN           NaN
# GesturePebbleZ2                                 NaN      NaN           NaN
# GunPoint                                        NaN      NaN           NaN
# GunPointAgeSpan                                 NaN      NaN           NaN
# GunPointMaleVersusFemale                        NaN      NaN           NaN
# GunPointOldVersusYoung                          NaN      NaN           NaN
# Ham                                             NaN      NaN           NaN
# HandOutlines                                    NaN      NaN           NaN
# Haptics                                         NaN      NaN           NaN
# Herring                                         NaN      NaN           NaN
# HouseTwenty                                     NaN      NaN           NaN
# InlineSkate                                     NaN      NaN           NaN
# InsectEPGRegularTrain                           NaN      NaN           NaN
# InsectEPGSmallTrain                             NaN      NaN           NaN
# InsectWingbeatSound                             NaN      NaN           NaN
# ItalyPowerDemand                                NaN      NaN           NaN
# LargeKitchenAppliances                          NaN      NaN           NaN
# Lightning2                                      NaN      NaN           NaN
# Lightning7                                      NaN      NaN           NaN
# Mallat                                          NaN      NaN           NaN
# Meat                                            NaN      NaN           NaN
# MedicalImages                                   NaN      NaN           NaN
# MelbournePedestrian                             NaN      NaN           NaN
# MiddlePhalanxOutlineAgeGroup                    NaN      NaN           NaN
# MiddlePhalanxOutlineCorrect                     NaN      NaN           NaN
# MiddlePhalanxTW                                 NaN      NaN           NaN
# MixedShapesRegularTrain                         NaN      NaN           NaN
# MixedShapesSmallTrain                           NaN      NaN           NaN
# MoteStrain                                      NaN      NaN           NaN
# NonInvasiveFetalECGThorax1                      NaN      NaN           NaN
# NonInvasiveFetalECGThorax2                      NaN      NaN           NaN
# OliveOil                                        NaN      NaN           NaN
# OSULeaf                                         NaN      NaN           NaN
# PhalangesOutlinesCorrect                        NaN      NaN           NaN
# Phoneme                                         NaN      NaN           NaN
# PickupGestureWiimoteZ                           NaN      NaN           NaN
# PigAirwayPressure                               NaN      NaN           NaN
# PigArtPressure                                  NaN      NaN           NaN
# PigCVP                                          NaN      NaN           NaN
# PLAID                                           NaN      NaN           NaN
# Plane                                           NaN      NaN           NaN
# PowerCons                                       NaN      NaN           NaN
# ProximalPhalanxOutlineAgeGroup                  NaN      NaN           NaN
# ProximalPhalanxOutlineCorrect                   NaN      NaN           NaN
# ProximalPhalanxTW                               NaN      NaN           NaN
# RefrigerationDevices                            NaN      NaN           NaN
# Rock                                            NaN      NaN           NaN
# ScreenType                                      NaN      NaN           NaN
# SemgHandGenderCh2                               NaN      NaN           NaN
# SemgHandMovementCh2                             NaN      NaN           NaN
# SemgHandSubjectCh2                              NaN      NaN           NaN
# ShakeGestureWiimoteZ                            NaN      NaN           NaN
# ShapeletSim                                     NaN      NaN           NaN
# ShapesAll                                       NaN      NaN           NaN
# SmallKitchenAppliances                          NaN      NaN           NaN
# SmoothSubspace                                  NaN      NaN           NaN
# SonyAIBORobotSurface1                           NaN      NaN           NaN
# SonyAIBORobotSurface2                           NaN      NaN           NaN
# StarLightCurves                                 NaN      NaN           NaN
# Strawberry                                      NaN      NaN           NaN
# SwedishLeaf                                     NaN      NaN           NaN
# Symbols                                         NaN      NaN           NaN
# SyntheticControl                                NaN      NaN           NaN
# ToeSegmentation1                                NaN      NaN           NaN
# ToeSegmentation2                                NaN      NaN           NaN
# Trace                                           NaN      NaN           NaN
# TwoLeadECG                                      NaN      NaN           NaN
# TwoPatterns                                     NaN      NaN           NaN
# UMD                                             NaN      NaN           NaN
# UWaveGestureLibraryAll                          NaN      NaN           NaN
# UWaveGestureLibraryX                            NaN      NaN           NaN
# UWaveGestureLibraryY                            NaN      NaN           NaN
# UWaveGestureLibraryZ                            NaN      NaN           NaN
# Wafer                                           NaN      NaN           NaN
# Wine                                            NaN      NaN           NaN
# WordSynonyms                                    NaN      NaN           NaN
# Worms                                           NaN      NaN           NaN
# WormsTwoClass                                   NaN      NaN           NaN
# Yoga                                            NaN      NaN           NaN
#
# classifier
# metric                         F1-Score
# ACSF1                               NaN
# Adiac                               NaN
# ArrowHead                           NaN
# Beef                                NaN
# BeetleFly                           NaN
# BirdChicken                         NaN
# BME                                 NaN
# Car                                 NaN
# CBF                                 NaN
# Chinatown                           NaN
# ChlorineConcentration               NaN
# CinCECGTorso                        NaN
# Coffee                              NaN
# Computers                           NaN
# CricketX                            NaN
# CricketY                            NaN
# CricketZ                            NaN
# Crop                                NaN
# DiatomSizeReduction                 NaN
# DistalPhalanxOutlineAgeGroup        NaN
# DistalPhalanxOutlineCorrect         NaN
# DistalPhalanxTW                     NaN
# DodgerLoopDay                       NaN
# DodgerLoopGame                      NaN
# DodgerLoopWeekend                   NaN
# Earthquakes                         NaN
# ECG200                              NaN
# ECG5000                             NaN
# ECGFiveDays                         NaN
# ElectricDevices                     NaN
# EOGHorizontalSignal                 NaN
# EOGVerticalSignal                   NaN
# EthanolLevel                        NaN
# FaceAll                             NaN
# FaceFour                            NaN
# FacesUCR                            NaN
# FiftyWords                          NaN
# Fish                                NaN
# FordA                               NaN
# FordB                               NaN
# FreezerRegularTrain                 NaN
# FreezerSmallTrain                   NaN
# Fungi                               NaN
# GestureMidAirD1                     NaN
# GestureMidAirD2                     NaN
# GestureMidAirD3                     NaN
# GesturePebbleZ1                     NaN
# GesturePebbleZ2                     NaN
# GunPoint                            NaN
# GunPointAgeSpan                     NaN
# GunPointMaleVersusFemale            NaN
# GunPointOldVersusYoung              NaN
# Ham                                 NaN
# HandOutlines                        NaN
# Haptics                             NaN
# Herring                             NaN
# HouseTwenty                         NaN
# InlineSkate                         NaN
# InsectEPGRegularTrain               NaN
# InsectEPGSmallTrain                 NaN
# InsectWingbeatSound                 NaN
# ItalyPowerDemand                    NaN
# LargeKitchenAppliances              NaN
# Lightning2                          NaN
# Lightning7                          NaN
# Mallat                              NaN
# Meat                                NaN
# MedicalImages                       NaN
# MelbournePedestrian                 NaN
# MiddlePhalanxOutlineAgeGroup        NaN
# MiddlePhalanxOutlineCorrect         NaN
# MiddlePhalanxTW                     NaN
# MixedShapesRegularTrain             NaN
# MixedShapesSmallTrain               NaN
# MoteStrain                          NaN
# NonInvasiveFetalECGThorax1          NaN
# NonInvasiveFetalECGThorax2          NaN
# OliveOil                            NaN
# OSULeaf                             NaN
# PhalangesOutlinesCorrect            NaN
# Phoneme                             NaN
# PickupGestureWiimoteZ               NaN
# PigAirwayPressure                   NaN
# PigArtPressure                      NaN
# PigCVP                              NaN
# PLAID                               NaN
# Plane                               NaN
# PowerCons                           NaN
# ProximalPhalanxOutlineAgeGroup      NaN
# ProximalPhalanxOutlineCorrect       NaN
# ProximalPhalanxTW                   NaN
# RefrigerationDevices                NaN
# Rock                                NaN
# ScreenType                          NaN
# SemgHandGenderCh2                   NaN
# SemgHandMovementCh2                 NaN
# SemgHandSubjectCh2                  NaN
# ShakeGestureWiimoteZ                NaN
# ShapeletSim                         NaN
# ShapesAll                           NaN
# SmallKitchenAppliances              NaN
# SmoothSubspace                      NaN
# SonyAIBORobotSurface1               NaN
# SonyAIBORobotSurface2               NaN
# StarLightCurves                     NaN
# Strawberry                          NaN
# SwedishLeaf                         NaN
# Symbols                             NaN
# SyntheticControl                    NaN
# ToeSegmentation1                    NaN
# ToeSegmentation2                    NaN
# Trace                               NaN
# TwoLeadECG                          NaN
# TwoPatterns                         NaN
# UMD                                 NaN
# UWaveGestureLibraryAll              NaN
# UWaveGestureLibraryX                NaN
# UWaveGestureLibraryY                NaN
# UWaveGestureLibraryZ                NaN
# Wafer                               NaN
# Wine                                NaN
# WordSynonyms                        NaN
# Worms                               NaN
# WormsTwoClass                       NaN
# Yoga                                NaN

# %% [markdown]
# ## Shapelets-based classifier results

# %%
with open(os.path.join("results", "shapelets_results.pkl"), "rb") as f:
    data = pickle.load(f)
data
# Out:
# classifier                     RandomForestClassifier            \
# metric                                       Accuracy  F1-Score
# ACSF1                                        0.380000  0.387577
# Adiac                                        0.493606  0.477736
# ArrowHead                                    0.714286  0.707066
# Beef                                         0.666667  0.680808
# BeetleFly                                    0.900000  0.898990
# BirdChicken                                  0.900000  0.898990
# BME                                          0.860000  0.858469
# Car                                          0.750000  0.751467
# CBF                                          0.943333  0.943330
# Chinatown                                    0.973761  0.967556
# ChlorineConcentration                        0.447135  0.386044
# CinCECGTorso                                 0.576812  0.588361
# Coffee                                       0.928571  0.927083
# Computers                                    0.540000  0.539639
# CricketX                                     0.138462  0.139258
# CricketY                                     0.156410  0.154647
# CricketZ                                     0.179487  0.176663
# Crop                                         0.266131  0.253963
# DiatomSizeReduction                          0.879085  0.833158
# DistalPhalanxOutlineAgeGroup                 0.697842  0.695785
# DistalPhalanxOutlineCorrect                  0.673913  0.662848
# DistalPhalanxTW                              0.647482  0.483519
# DodgerLoopDay                                0.312500  0.304780
# DodgerLoopGame                                    NaN       NaN
# DodgerLoopWeekend                                 NaN       NaN
# Earthquakes                                       NaN       NaN
# ECG200                                       0.840000  0.824176
# ECG5000                                      0.904222  0.373380
# ECGFiveDays                                  0.997677  0.997677
# ElectricDevices                              0.309947  0.118707
# EOGHorizontalSignal                          0.146409  0.147170
# EOGVerticalSignal                            0.116022  0.119193
# EthanolLevel                                      NaN       NaN
# FaceAll                                      0.162130  0.170184
# FaceFour                                     1.000000  1.000000
# FacesUCR                                     0.578537  0.535090
# FiftyWords                                   0.158242  0.044645
# Fish                                         0.400000  0.399818
# FordA                                             NaN       NaN
# FordB                                             NaN       NaN
# FreezerRegularTrain                          0.996491  0.996491
# FreezerSmallTrain                            0.998947  0.998947
# Fungi                                             NaN       NaN
# GunPoint                                     0.986667  0.986664
# GunPointAgeSpan                              0.952532  0.952527
# GunPointMaleVersusFemale                     0.949367  0.949294
# GunPointOldVersusYoung                       0.939683  0.939330
# Ham                                          0.466667  0.455556
# HandOutlines                                 0.610811  0.582720
# Haptics                                      0.288961  0.283490
# Herring                                      0.609375  0.551444
# HouseTwenty                                  0.806723  0.797034
# InlineSkate                                  0.170909  0.167913
# InsectEPGRegularTrain                        0.899598  0.872820
# InsectEPGSmallTrain                          0.895582  0.853676
# InsectWingbeatSound                          0.283838  0.278956
# ItalyPowerDemand                             0.961127  0.961124
# LargeKitchenAppliances                       0.317333  0.317096
# Lightning2                                   0.590164  0.551074
# Lightning7                                   0.671233  0.643836
# Mallat                                       0.917697  0.915270
# Meat                                         0.883333  0.882244
# MedicalImages                                0.506579  0.276717
# MiddlePhalanxOutlineAgeGroup                 0.545455  0.448494
# MiddlePhalanxOutlineCorrect                  0.536082  0.505830
# MiddlePhalanxTW                              0.525974  0.384977
# MixedShapesRegularTrain                      0.333196  0.326032
# MixedShapesSmallTrain                        0.538144  0.529555
# MoteStrain                                   0.926518  0.925987
# NonInvasiveFetalECGThorax1                        NaN       NaN
# NonInvasiveFetalECGThorax2                        NaN       NaN
# OliveOil                                     0.800000  0.733256
# OSULeaf                                      0.413223  0.392561
# PhalangesOutlinesCorrect                     0.546620  0.491275
# Phoneme                                           NaN       NaN
# PigAirwayPressure                            0.346154  0.335846
# PigArtPressure                               0.221154  0.196874
# PigCVP                                       0.110577  0.108817
# Plane                                        1.000000  1.000000
# PowerCons                                    0.888889  0.888765
# ProximalPhalanxOutlineAgeGroup               0.795122  0.648931
# ProximalPhalanxOutlineCorrect                0.659794  0.618247
# ProximalPhalanxTW                            0.756098  0.441651
# RefrigerationDevices                         0.373333  0.371743
# Rock                                         0.480000  0.459750
# ScreenType                                   0.482667  0.481419
# SemgHandGenderCh2                            0.600000  0.580928
# SemgHandMovementCh2                          0.224444  0.224628
# SemgHandSubjectCh2                           0.320000  0.320617
# ShapeletSim                                  0.977778  0.977767
# ShapesAll                                    0.096667  0.095864
# SmallKitchenAppliances                       0.469333  0.447054
# SmoothSubspace                               0.886667  0.886265
# SonyAIBORobotSurface1                        0.921797  0.921207
# SonyAIBORobotSurface2                        0.926548  0.922911
# StarLightCurves                              0.716974  0.666424
# Strawberry                                   0.783784  0.770820
# SwedishLeaf                                  0.435200  0.424741
# Symbols                                      0.927638  0.928272
# SyntheticControl                             0.850000  0.847593
# ToeSegmentation1                             0.969298  0.969250
# ToeSegmentation2                             0.846154  0.796938
# Trace                                        1.000000  1.000000
# TwoLeadECG                                   0.990342  0.990342
# TwoPatterns                                  0.560500  0.555573
# UMD                                          0.958333  0.958324
# UWaveGestureLibraryAll                       0.218035  0.216633
# UWaveGestureLibraryX                         0.220268  0.218921
# UWaveGestureLibraryY                         0.191792  0.188850
# UWaveGestureLibraryZ                         0.296203  0.295207
# Wafer                                        0.904770  0.761567
# Wine                                         0.629630  0.629121
# WordSynonyms                                 0.134796  0.067135
# Worms                                        0.584416  0.504784
# WormsTwoClass                                0.558442  0.549242
# Yoga                                         0.541667  0.540791
#
# classifier                     ExtraTreesClassifier           XGBClassifier  \
# metric                                     Accuracy  F1-Score      Accuracy
# ACSF1                                      0.330000  0.343535      0.390000
# Adiac                                      0.529412  0.497986      0.452685
# ArrowHead                                  0.737143  0.734349      0.645714
# Beef                                       0.600000  0.613784      0.633333
# BeetleFly                                  0.900000  0.898990           NaN
# BirdChicken                                0.900000  0.898990           NaN
# BME                                        0.906667  0.906277      0.766667
# Car                                        0.733333  0.735332      0.683333
# CBF                                        0.973333  0.973408      0.865556
# Chinatown                                  0.976676  0.971070           NaN
# ChlorineConcentration                      0.460156  0.393551      0.551302
# CinCECGTorso                               0.569565  0.582110      0.550000
# Coffee                                     0.892857  0.889328           NaN
# Computers                                  0.532000  0.531633           NaN
# CricketX                                   0.135897  0.138224      0.130769
# CricketY                                   0.153846  0.153069      0.169231
# CricketZ                                   0.210256  0.207462      0.192308
# Crop                                       0.265714  0.253995      0.200476
# DiatomSizeReduction                        0.905229  0.891726      0.875817
# DistalPhalanxOutlineAgeGroup               0.719424  0.727277      0.683453
# DistalPhalanxOutlineCorrect                0.663043  0.648032           NaN
# DistalPhalanxTW                            0.669065  0.496209      0.654676
# DodgerLoopDay                              0.325000  0.320603      0.325000
# DodgerLoopGame                                  NaN       NaN           NaN
# DodgerLoopWeekend                               NaN       NaN           NaN
# Earthquakes                                     NaN       NaN           NaN
# ECG200                                     0.850000  0.834052           NaN
# ECG5000                                    0.904889  0.384185      0.898889
# ECGFiveDays                                1.000000  1.000000           NaN
# ElectricDevices                            0.309947  0.118707      0.309947
# EOGHorizontalSignal                        0.149171  0.149445      0.209945
# EOGVerticalSignal                          0.113260  0.116095      0.151934
# EthanolLevel                                    NaN       NaN           NaN
# FaceAll                                    0.151479  0.160412      0.171006
# FaceFour                                   1.000000  1.000000      0.965909
# FacesUCR                                   0.621463  0.594119      0.560000
# FiftyWords                                 0.160440  0.044687      0.204396
# Fish                                       0.382857  0.366572      0.417143
# FordA                                           NaN       NaN           NaN
# FordB                                           NaN       NaN           NaN
# FreezerRegularTrain                        0.996491  0.996491           NaN
# FreezerSmallTrain                          0.998947  0.998947           NaN
# Fungi                                           NaN       NaN           NaN
# GunPoint                                   0.993333  0.993331           NaN
# GunPointAgeSpan                            0.965190  0.965190           NaN
# GunPointMaleVersusFemale                   0.955696  0.955609           NaN
# GunPointOldVersusYoung                     0.952381  0.952103           NaN
# Ham                                        0.533333  0.527157           NaN
# HandOutlines                               0.610811  0.582720           NaN
# Haptics                                    0.301948  0.297499      0.269481
# Herring                                    0.609375  0.551444           NaN
# HouseTwenty                                0.773109  0.759812           NaN
# InlineSkate                                0.178182  0.176077      0.187273
# InsectEPGRegularTrain                      0.915663  0.886986      0.899598
# InsectEPGSmallTrain                        0.875502  0.811720      0.815261
# InsectWingbeatSound                        0.279293  0.275483      0.281818
# ItalyPowerDemand                           0.959184  0.959175           NaN
# LargeKitchenAppliances                     0.298667  0.296893      0.298667
# Lightning2                                 0.639344  0.590854           NaN
# Lightning7                                 0.643836  0.611451      0.575342
# Mallat                                     0.915139  0.913138      0.871215
# Meat                                       0.883333  0.882244      0.933333
# MedicalImages                              0.501316  0.259868      0.507895
# MiddlePhalanxOutlineAgeGroup               0.512987  0.410245      0.493506
# MiddlePhalanxOutlineCorrect                0.536082  0.509287           NaN
# MiddlePhalanxTW                            0.487013  0.357528      0.525974
# MixedShapesRegularTrain                    0.336495  0.329119      0.399175
# MixedShapesSmallTrain                      0.539794  0.525839      0.497320
# MoteStrain                                 0.946486  0.946293           NaN
# NonInvasiveFetalECGThorax1                      NaN       NaN           NaN
# NonInvasiveFetalECGThorax2                      NaN       NaN           NaN
# OliveOil                                   0.866667  0.878730      0.766667
# OSULeaf                                    0.409091  0.379451      0.421488
# PhalangesOutlinesCorrect                   0.550117  0.494761           NaN
# Phoneme                                         NaN       NaN           NaN
# PigAirwayPressure                          0.336538  0.324623      0.235577
# PigArtPressure                             0.221154  0.194265      0.250000
# PigCVP                                     0.110577  0.106152      0.110577
# Plane                                      1.000000  1.000000      1.000000
# PowerCons                                  0.883333  0.883301           NaN
# ProximalPhalanxOutlineAgeGroup             0.795122  0.661267      0.800000
# ProximalPhalanxOutlineCorrect              0.659794  0.620160           NaN
# ProximalPhalanxTW                          0.780488  0.472323      0.765854
# RefrigerationDevices                       0.360000  0.358079      0.429333
# Rock                                       0.440000  0.431319      0.380000
# ScreenType                                 0.437333  0.436794      0.442667
# SemgHandGenderCh2                          0.596667  0.578059           NaN
# SemgHandMovementCh2                        0.226667  0.226817      0.217778
# SemgHandSubjectCh2                         0.322222  0.322703      0.393333
# ShapeletSim                                1.000000  1.000000           NaN
# ShapesAll                                  0.093333  0.092737      0.115000
# SmallKitchenAppliances                     0.469333  0.447054      0.469333
# SmoothSubspace                             0.886667  0.885918      0.866667
# SonyAIBORobotSurface1                      0.926789  0.926215           NaN
# SonyAIBORobotSurface2                      0.921301  0.917972           NaN
# StarLightCurves                            0.716003  0.665798      0.815809
# Strawberry                                 0.781081  0.767637           NaN
# SwedishLeaf                                0.420800  0.411403      0.444800
# Symbols                                    0.960804  0.961241      0.805025
# SyntheticControl                           0.856667  0.856395      0.846667
# ToeSegmentation1                           0.960526  0.960434           NaN
# ToeSegmentation2                           0.869231  0.821932           NaN
# Trace                                      1.000000  1.000000      1.000000
# TwoLeadECG                                 0.995610  0.995610           NaN
# TwoPatterns                                0.557500  0.552575      0.625250
# UMD                                        0.951389  0.951402      0.923611
# UWaveGestureLibraryAll                     0.216360  0.214987      0.245673
# UWaveGestureLibraryX                       0.221664  0.219932      0.305137
# UWaveGestureLibraryY                       0.192071  0.189222      0.243719
# UWaveGestureLibraryZ                       0.294807  0.293943      0.376047
# Wafer                                      0.903310  0.759873           NaN
# Wine                                       0.611111  0.607748           NaN
# WordSynonyms                               0.133229  0.063581      0.202194
# Worms                                      0.558442  0.483889      0.545455
# WormsTwoClass                              0.558442  0.549242           NaN
# Yoga                                       0.541000  0.540096           NaN
#
# classifier
# metric                          F1-Score
# ACSF1                           0.398661
# Adiac                           0.454327
# ArrowHead                       0.643198
# Beef                            0.644314
# BeetleFly                            NaN
# BirdChicken                          NaN
# BME                             0.766085
# Car                             0.694766
# CBF                             0.863682
# Chinatown                            NaN
# ChlorineConcentration           0.381406
# CinCECGTorso                    0.559022
# Coffee                               NaN
# Computers                            NaN
# CricketX                        0.129515
# CricketY                        0.153756
# CricketZ                        0.180266
# Crop                            0.150111
# DiatomSizeReduction             0.854251
# DistalPhalanxOutlineAgeGroup    0.675249
# DistalPhalanxOutlineCorrect          NaN
# DistalPhalanxTW                 0.514872
# DodgerLoopDay                   0.322481
# DodgerLoopGame                       NaN
# DodgerLoopWeekend                    NaN
# Earthquakes                          NaN
# ECG200                               NaN
# ECG5000                         0.385183
# ECGFiveDays                          NaN
# ElectricDevices                 0.118707
# EOGHorizontalSignal             0.198258
# EOGVerticalSignal               0.138704
# EthanolLevel                         NaN
# FaceAll                         0.186092
# FaceFour                        0.960990
# FacesUCR                        0.525619
# FiftyWords                      0.049653
# Fish                            0.420185
# FordA                                NaN
# FordB                                NaN
# FreezerRegularTrain                  NaN
# FreezerSmallTrain                    NaN
# Fungi                                NaN
# GunPoint                             NaN
# GunPointAgeSpan                      NaN
# GunPointMaleVersusFemale             NaN
# GunPointOldVersusYoung               NaN
# Ham                                  NaN
# HandOutlines                         NaN
# Haptics                         0.262440
# Herring                              NaN
# HouseTwenty                          NaN
# InlineSkate                     0.181779
# InsectEPGRegularTrain           0.867468
# InsectEPGSmallTrain             0.768473
# InsectWingbeatSound             0.278809
# ItalyPowerDemand                     NaN
# LargeKitchenAppliances          0.296893
# Lightning2                           NaN
# Lightning7                      0.554199
# Mallat                          0.869257
# Meat                            0.933250
# MedicalImages                   0.237387
# MiddlePhalanxOutlineAgeGroup    0.419612
# MiddlePhalanxOutlineCorrect          NaN
# MiddlePhalanxTW                 0.377319
# MixedShapesRegularTrain         0.371488
# MixedShapesSmallTrain           0.492312
# MoteStrain                           NaN
# NonInvasiveFetalECGThorax1           NaN
# NonInvasiveFetalECGThorax2           NaN
# OliveOil                        0.696342
# OSULeaf                         0.382512
# PhalangesOutlinesCorrect             NaN
# Phoneme                              NaN
# PigAirwayPressure               0.219480
# PigArtPressure                  0.215650
# PigCVP                          0.091810
# Plane                           1.000000
# PowerCons                            NaN
# ProximalPhalanxOutlineAgeGroup  0.654425
# ProximalPhalanxOutlineCorrect        NaN
# ProximalPhalanxTW               0.435782
# RefrigerationDevices            0.426169
# Rock                            0.363833
# ScreenType                      0.440670
# SemgHandGenderCh2                    NaN
# SemgHandMovementCh2             0.208704
# SemgHandSubjectCh2              0.378277
# ShapeletSim                          NaN
# ShapesAll                       0.100694
# SmallKitchenAppliances          0.447054
# SmoothSubspace                  0.867435
# SonyAIBORobotSurface1                NaN
# SonyAIBORobotSurface2                NaN
# StarLightCurves                 0.752870
# Strawberry                           NaN
# SwedishLeaf                     0.429269
# Symbols                         0.804155
# SyntheticControl                0.845313
# ToeSegmentation1                     NaN
# ToeSegmentation2                     NaN
# Trace                           1.000000
# TwoLeadECG                           NaN
# TwoPatterns                     0.603060
# UMD                             0.923279
# UWaveGestureLibraryAll          0.226777
# UWaveGestureLibraryX            0.261042
# UWaveGestureLibraryY            0.230424
# UWaveGestureLibraryZ            0.334731
# Wafer                                NaN
# Wine                                 NaN
# WordSynonyms                    0.065558
# Worms                           0.446058
# WormsTwoClass                        NaN
# Yoga                                 NaN

# %% [markdown]
# ## CNN and time series plot based classifier

# %%
with open(os.path.join("results", "cnn_results.pkl"), "rb") as f:
    data = pickle.load(f)
data
# Out:
# classifier                     RecurrencePlot            \
# metric                               Accuracy  F1-Score
# ACSF1                                0.120000  0.093979
# Adiac                                0.046036  0.005002
# AllGestureWiimoteX                   0.130000  0.106590
# AllGestureWiimoteY                   0.117143  0.089905
# AllGestureWiimoteZ                   0.124286  0.096083
# ArrowHead                            0.388571  0.322165
# Beef                                 0.166667  0.100000
# BeetleFly                            0.500000  0.333333
# BirdChicken                          0.500000  0.333333
# BME                                  0.353333  0.206941
# Car                                  0.250000  0.131605
# CBF                                  0.334444  0.179700
# Chinatown                            0.603499  0.601026
# ChlorineConcentration                0.232813  0.144730
# CinCECGTorso                         0.230435  0.102192
# Coffee                               0.464286  0.317073
# Computers                            0.500000  0.333333
# CricketX                             0.169231  0.129535
# CricketY                             0.153846  0.129815
# CricketZ                             0.089744  0.064691
# Crop                                 0.098810  0.065233
# DiatomSizeReduction                  0.473856  0.418986
# DistalPhalanxOutlineAgeGroup         0.223022  0.151299
# DistalPhalanxOutlineCorrect          0.583333  0.368421
# DistalPhalanxTW                      0.438849  0.231012
# DodgerLoopDay                             NaN       NaN
# DodgerLoopGame                            NaN       NaN
# DodgerLoopWeekend                         NaN       NaN
# Earthquakes                          0.748201  0.427984
# ECG200                               0.360000  0.264706
# ECG5000                              0.192222  0.084536
# ECGFiveDays                          0.447154  0.314289
# ElectricDevices                      0.322656  0.131709
# EOGHorizontalSignal                  0.058011  0.039207
# EOGVerticalSignal                    0.060773  0.032957
# EthanolLevel                         0.298000  0.227062
# FaceAll                              0.205917  0.187226
# FaceFour                             0.090909  0.072333
# FacesUCR                             0.182439  0.162080
# FiftyWords                           0.008791  0.005666
# Fish                                 0.234286  0.179805
# FordA                                0.557576  0.539718
# FordB                                0.591358  0.581389
# FreezerRegularTrain                  0.717895  0.714338
# FreezerSmallTrain                    0.502456  0.338768
# Fungi                                0.096774  0.055787
# GestureMidAirD1                      0.053846  0.028834
# GestureMidAirD2                      0.046154  0.034131
# GestureMidAirD3                      0.046154  0.042399
# GesturePebbleZ1                      0.174419  0.108763
# GesturePebbleZ2                      0.151899  0.066126
# GunPoint                             0.520000  0.448529
# GunPointAgeSpan                      0.506329  0.385766
# GunPointMaleVersusFemale             0.610759  0.570268
# GunPointOldVersusYoung               0.542857  0.540816
# Ham                                  0.504762  0.442857
# HandOutlines                         0.651351  0.446769
# Haptics                              0.344156  0.328240
# Herring                              0.531250  0.346939
# HouseTwenty                          0.420168  0.295858
# InlineSkate                          0.120000  0.086891
# InsectEPGRegularTrain                0.232932  0.198065
# InsectEPGSmallTrain                  0.180723  0.157731
# InsectWingbeatSound                  0.133333  0.129754
# ItalyPowerDemand                     0.531584  0.404743
# LargeKitchenAppliances               0.333333  0.166667
# Lightning2                           0.688525  0.685482
# Lightning7                           0.109589  0.042455
# Mallat                               0.171855  0.098455
# Meat                                 0.466667  0.363636
# MedicalImages                        0.261842  0.125666
# MelbournePedestrian                       NaN       NaN
# MiddlePhalanxOutlineAgeGroup         0.181818  0.155249
# MiddlePhalanxOutlineCorrect          0.594502  0.421919
# MiddlePhalanxTW                      0.188312  0.080289
# MixedShapesRegularTrain              0.205773  0.147205
# MixedShapesSmallTrain                0.186392  0.172353
# MoteStrain                           0.589457  0.583150
# NonInvasiveFetalECGThorax1           0.084478  0.035948
# NonInvasiveFetalECGThorax2           0.069720  0.019235
# OliveOil                             0.400000  0.142857
# OSULeaf                              0.185950  0.168489
# PhalangesOutlinesCorrect             0.642191  0.516859
# Phoneme                              0.035865  0.015845
# PickupGestureWiimoteZ                0.100000  0.036667
# PigAirwayPressure                    0.009615  0.009615
# PigArtPressure                       0.009615  0.002024
# PigCVP                               0.014423  0.009026
# PLAID                                0.096834  0.066865
# Plane                                0.371429  0.331487
# PowerCons                            0.811111  0.810901
# ProximalPhalanxOutlineAgeGroup       0.487805  0.218579
# ProximalPhalanxOutlineCorrect        0.371134  0.304619
# ProximalPhalanxTW                    0.497561  0.243830
# RefrigerationDevices                 0.317333  0.160594
# Rock                                 0.180000  0.076271
# ScreenType                           0.333333  0.166667
# SemgHandGenderCh2                    0.595000  0.593282
# SemgHandMovementCh2                  0.173333  0.084862
# SemgHandSubjectCh2                   0.273333  0.211041
# ShakeGestureWiimoteZ                 0.140000  0.102231
# ShapeletSim                          0.394444  0.392174
# ShapesAll                            0.008333  0.001200
# SmallKitchenAppliances               0.333333  0.166667
# SmoothSubspace                       0.373333  0.300465
# SonyAIBORobotSurface1                0.590682  0.560704
# SonyAIBORobotSurface2                0.344176  0.315211
# StarLightCurves                      0.228752  0.229677
# Strawberry                           0.670270  0.522146
# SwedishLeaf                          0.147200  0.125248
# Symbols                              0.245226  0.167011
# SyntheticControl                     0.083333  0.066950
# ToeSegmentation1                     0.473684  0.321429
# ToeSegmentation2                     0.584615  0.489974
# Trace                                0.240000  0.097561
# TwoLeadECG                           0.506585  0.499970
# TwoPatterns                          0.275750  0.263912
# UMD                                  0.326389  0.177065
# UWaveGestureLibraryAll               0.204355  0.211592
# UWaveGestureLibraryX                 0.153825  0.128445
# UWaveGestureLibraryY                 0.194863  0.181357
# UWaveGestureLibraryZ                 0.132887  0.098668
# Wafer                                0.766548  0.575194
# Wine                                 0.500000  0.333333
# WordSynonyms                         0.059561  0.030302
# Worms                                0.376623  0.314393
# WormsTwoClass                        0.519481  0.518180
# Yoga                                 0.554333  0.529364
#
# classifier                     MarkovTransitiveFields            \
# metric                                       Accuracy  F1-Score
# ACSF1                                        0.160000  0.108373
# Adiac                                        0.061381  0.026534
# AllGestureWiimoteX                                NaN       NaN
# AllGestureWiimoteY                                NaN       NaN
# AllGestureWiimoteZ                                NaN       NaN
# ArrowHead                                    0.325714  0.258793
# Beef                                         0.233333  0.199365
# BeetleFly                                    0.600000  0.600000
# BirdChicken                                  0.500000  0.333333
# BME                                          0.406667  0.324786
# Car                                          0.366667  0.284754
# CBF                                          0.265556  0.179862
# Chinatown                                    0.274052  0.215103
# ChlorineConcentration                        0.509375  0.323319
# CinCECGTorso                                 0.276087  0.246208
# Coffee                                       0.464286  0.317073
# Computers                                    0.500000  0.497095
# CricketX                                     0.120513  0.104694
# CricketY                                     0.128205  0.112601
# CricketZ                                     0.141026  0.129985
# Crop                                         0.332798  0.318808
# DiatomSizeReduction                          0.284314  0.110687
# DistalPhalanxOutlineAgeGroup                 0.453237  0.422649
# DistalPhalanxOutlineCorrect                  0.583333  0.368421
# DistalPhalanxTW                              0.179856  0.107191
# DodgerLoopDay                                     NaN       NaN
# DodgerLoopGame                                    NaN       NaN
# DodgerLoopWeekend                                 NaN       NaN
# Earthquakes                                  0.589928  0.556805
# ECG200                                       0.760000  0.708596
# ECG5000                                      0.482444  0.175111
# ECGFiveDays                                  0.413473  0.349504
# ElectricDevices                              0.482039  0.430942
# EOGHorizontalSignal                          0.055249  0.024579
# EOGVerticalSignal                            0.069061  0.035632
# EthanolLevel                                 0.252000  0.100639
# FaceAll                                      0.127219  0.108636
# FaceFour                                     0.295455  0.174878
# FacesUCR                                     0.120000  0.098868
# FiftyWords                                   0.008791  0.004698
# Fish                                         0.251429  0.218421
# FordA                                        0.643182  0.638944
# FordB                                        0.574074  0.570190
# FreezerRegularTrain                          0.499649  0.445583
# FreezerSmallTrain                            0.482456  0.475637
# Fungi                                        0.048387  0.026411
# GestureMidAirD1                              0.061538  0.026709
# GestureMidAirD2                              0.069231  0.053988
# GestureMidAirD3                              0.046154  0.016239
# GesturePebbleZ1                              0.162791  0.051852
# GesturePebbleZ2                              0.170886  0.150365
# GunPoint                                     0.293333  0.293333
# GunPointAgeSpan                              0.762658  0.758594
# GunPointMaleVersusFemale                     0.518987  0.486047
# GunPointOldVersusYoung                       0.625397  0.552686
# Ham                                          0.457143  0.401560
# HandOutlines                                 0.451351  0.446952
# Haptics                                      0.266234  0.243261
# Herring                                      0.609375  0.489633
# HouseTwenty                                  0.386555  0.278788
# InlineSkate                                  0.156364  0.111228
# InsectEPGRegularTrain                        0.353414  0.244775
# InsectEPGSmallTrain                          0.317269  0.269074
# InsectWingbeatSound                          0.180808  0.157853
# ItalyPowerDemand                             0.501458  0.333981
# LargeKitchenAppliances                       0.429333  0.410839
# Lightning2                                   0.491803  0.491803
# Lightning7                                   0.315068  0.144862
# Mallat                                       0.117271  0.031797
# Meat                                         0.500000  0.412698
# MedicalImages                                0.217105  0.107406
# MelbournePedestrian                               NaN       NaN
# MiddlePhalanxOutlineAgeGroup                 0.616883  0.379275
# MiddlePhalanxOutlineCorrect                  0.597938  0.472279
# MiddlePhalanxTW                              0.292208  0.108602
# MixedShapesRegularTrain                      0.270103  0.085943
# MixedShapesSmallTrain                        0.283711  0.171540
# MoteStrain                                   0.458466  0.408466
# NonInvasiveFetalECGThorax1                   0.042748  0.015461
# NonInvasiveFetalECGThorax2                   0.054962  0.030875
# OliveOil                                     0.300000  0.115385
# OSULeaf                                      0.165289  0.171251
# PhalangesOutlinesCorrect                     0.599068  0.559211
# Phoneme                                      0.029008  0.020747
# PickupGestureWiimoteZ                        0.100000  0.041259
# PigAirwayPressure                            0.033654  0.013804
# PigArtPressure                               0.033654  0.007217
# PigCVP                                       0.038462  0.013490
# PLAID                                        0.117318  0.041470
# Plane                                        0.161905  0.185941
# PowerCons                                    0.577778  0.570136
# ProximalPhalanxOutlineAgeGroup               0.082927  0.051051
# ProximalPhalanxOutlineCorrect                0.683849  0.406122
# ProximalPhalanxTW                            0.068293  0.021309
# RefrigerationDevices                         0.330667  0.234277
# Rock                                         0.180000  0.076271
# ScreenType                                   0.429333  0.426663
# SemgHandGenderCh2                            0.691667  0.536710
# SemgHandMovementCh2                          0.097778  0.035625
# SemgHandSubjectCh2                           0.200000  0.066667
# ShakeGestureWiimoteZ                         0.100000  0.047356
# ShapeletSim                                  0.500000  0.333333
# ShapesAll                                    0.021667  0.009759
# SmallKitchenAppliances                       0.325333  0.166326
# SmoothSubspace                               0.400000  0.371021
# SonyAIBORobotSurface1                        0.450915  0.366843
# SonyAIBORobotSurface2                        0.641133  0.456957
# StarLightCurves                              0.773555  0.552942
# Strawberry                                   0.435135  0.389656
# SwedishLeaf                                  0.116800  0.114983
# Symbols                                      0.177889  0.070215
# SyntheticControl                             0.273333  0.272650
# ToeSegmentation1                             0.473684  0.395493
# ToeSegmentation2                             0.184615  0.155844
# Trace                                        0.240000  0.165407
# TwoLeadECG                                   0.500439  0.333528
# TwoPatterns                                  0.310750  0.303504
# UMD                                          0.263889  0.212667
# UWaveGestureLibraryAll                       0.159687  0.074716
# UWaveGestureLibraryX                         0.164154  0.132145
# UWaveGestureLibraryY                         0.123953  0.035853
# UWaveGestureLibraryZ                              NaN       NaN
# Wafer                                        0.888222  0.476120
# Wine                                         0.518519  0.441971
# WordSynonyms                                 0.059561  0.031178
# Worms                                        0.259740  0.232802
# WormsTwoClass                                0.545455  0.512570
# Yoga                                         0.619667  0.615535
#
# classifier                     GramianAngular
# metric                               Accuracy  F1-Score
# ACSF1                                0.160000  0.058462
# Adiac                                0.092072  0.041545
# AllGestureWiimoteX                   0.095714  0.039751
# AllGestureWiimoteY                   0.112857  0.090856
# AllGestureWiimoteZ                   0.098571  0.077634
# ArrowHead                            0.348571  0.263072
# Beef                                 0.166667  0.105172
# BeetleFly                            0.700000  0.696970
# BirdChicken                          0.650000  0.641944
# BME                                  0.493333  0.495043
# Car                                  0.266667  0.195164
# CBF                                  0.427778  0.350981
# Chinatown                            0.361516  0.348762
# ChlorineConcentration                0.435417  0.349674
# CinCECGTorso                         0.283333  0.235724
# Coffee                               0.535714  0.348837
# Computers                            0.604000  0.603486
# CricketX                             0.151282  0.113995
# CricketY                             0.084615  0.072224
# CricketZ                             0.092308  0.069519
# Crop                                 0.254940  0.256208
# DiatomSizeReduction                  0.098039  0.044643
# DistalPhalanxOutlineAgeGroup         0.467626  0.212418
# DistalPhalanxOutlineCorrect          0.416667  0.294118
# DistalPhalanxTW                      0.129496  0.066717
# DodgerLoopDay                             NaN       NaN
# DodgerLoopGame                            NaN       NaN
# DodgerLoopWeekend                         NaN       NaN
# Earthquakes                          0.589928  0.544262
# ECG200                               0.370000  0.334812
# ECG5000                              0.068000  0.078023
# ECGFiveDays                          0.434379  0.365326
# ElectricDevices                      0.298016  0.216102
# EOGHorizontalSignal                  0.044199  0.032648
# EOGVerticalSignal                    0.146409  0.111371
# EthanolLevel                         0.248000  0.099359
# FaceAll                              0.268047  0.229814
# FaceFour                             0.215909  0.113270
# FacesUCR                             0.063415  0.026274
# FiftyWords                           0.021978  0.006787
# Fish                                 0.320000  0.271151
# FordA                                0.602273  0.529544
# FordB                                0.533333  0.433525
# FreezerRegularTrain                  0.446667  0.423863
# FreezerSmallTrain                    0.728772  0.709221
# Fungi                                0.053763  0.027053
# GestureMidAirD1                      0.092308  0.057904
# GestureMidAirD2                      0.030769  0.036144
# GestureMidAirD3                      0.076923  0.046343
# GesturePebbleZ1                      0.267442  0.231960
# GesturePebbleZ2                      0.303797  0.264638
# GunPoint                             0.566667  0.473855
# GunPointAgeSpan                      0.604430  0.596968
# GunPointMaleVersusFemale             0.424051  0.297778
# GunPointOldVersusYoung               0.577778  0.577710
# Ham                                  0.580952  0.496513
# HandOutlines                         0.645946  0.413274
# Haptics                              0.224026  0.203618
# Herring                              0.406250  0.288889
# HouseTwenty                          0.478992  0.450715
# InlineSkate                          0.140000  0.076744
# InsectEPGRegularTrain                0.453815  0.332676
# InsectEPGSmallTrain                  0.325301  0.334753
# InsectWingbeatSound                  0.187879  0.193871
# ItalyPowerDemand                     0.680272  0.674416
# LargeKitchenAppliances               0.250667  0.209516
# Lightning2                           0.688525  0.658817
# Lightning7                           0.219178  0.204617
# Mallat                               0.124947  0.030875
# Meat                                 0.333333  0.166667
# MedicalImages                        0.231579  0.083034
# MelbournePedestrian                       NaN       NaN
# MiddlePhalanxOutlineAgeGroup         0.551948  0.337302
# MiddlePhalanxOutlineCorrect          0.573883  0.371972
# MiddlePhalanxTW                      0.415584  0.194526
# MixedShapesRegularTrain              0.296907  0.138919
# MixedShapesSmallTrain                0.149691  0.091395
# MoteStrain                           0.658147  0.654304
# NonInvasiveFetalECGThorax1           0.056489  0.040700
# NonInvasiveFetalECGThorax2           0.025445  0.001271
# OliveOil                             0.166667  0.071429
# OSULeaf                              0.107438  0.094286
# PhalangesOutlinesCorrect             0.388112  0.386711
# Phoneme                              0.041667  0.015465
# PickupGestureWiimoteZ                0.120000  0.049495
# PigAirwayPressure                    0.014423  0.002319
# PigArtPressure                       0.014423  0.003533
# PigCVP                               0.024038  0.004293
# PLAID                                0.202980  0.110179
# Plane                                0.209524  0.122847
# PowerCons                            0.766667  0.765944
# ProximalPhalanxOutlineAgeGroup       0.414634  0.298329
# ProximalPhalanxOutlineCorrect        0.628866  0.624031
# ProximalPhalanxTW                    0.048780  0.015504
# RefrigerationDevices                 0.429333  0.385569
# Rock                                 0.280000  0.213426
# ScreenType                           0.293333  0.264470
# SemgHandGenderCh2                    0.726667  0.708444
# SemgHandMovementCh2                  0.224444  0.180456
# SemgHandSubjectCh2                   0.240000  0.248304
# ShakeGestureWiimoteZ                 0.080000  0.030812
# ShapeletSim                          0.500000  0.333333
# ShapesAll                            0.021667  0.012600
# SmallKitchenAppliances               0.317333  0.191855
# SmoothSubspace                       0.460000  0.445518
# SonyAIBORobotSurface1                0.484193  0.449439
# SonyAIBORobotSurface2                0.561385  0.428906
# StarLightCurves                      0.493929  0.508180
# Strawberry                           0.775676  0.747805
# SwedishLeaf                          0.337600  0.264611
# Symbols                              0.130653  0.043815
# SyntheticControl                     0.213333  0.122572
# ToeSegmentation1                     0.535088  0.521805
# ToeSegmentation2                     0.284615  0.283556
# Trace                                0.750000  0.754823
# TwoLeadECG                           0.503951  0.342812
# TwoPatterns                          0.279750  0.262791
# UMD                                  0.444444  0.448227
# UWaveGestureLibraryAll               0.158850  0.133632
# UWaveGestureLibraryX                 0.113065  0.042626
# UWaveGestureLibraryY                 0.121161  0.105810
# UWaveGestureLibraryZ                 0.125349  0.051030
# Wafer                                0.506165  0.420325
# Wine                                 0.425926  0.298701
# WordSynonyms                         0.097179  0.058748
# Worms                                0.181818  0.175886
# WormsTwoClass                        0.493506  0.493165
# Yoga                                 0.659333  0.634225
