# %%
import os
import pickle
import pandas as pd

pd.options.display.max_rows = 200

# %% [markdown]
# ## tsfresh features based classifier

# %%
pd.read_pickle(os.path.join("results", "tsfresh_results.pkl"))
# Out:
# classifier                     RandomForestClassifier           \
# metric                                       Accuracy F1-Score
# ACSF1                                             NaN      NaN
# Adiac                                             NaN      NaN
# AllGestureWiimoteX                                NaN      NaN
# AllGestureWiimoteY                                NaN      NaN
# AllGestureWiimoteZ                                NaN      NaN
# ArrowHead                                         NaN      NaN
# Beef                                              NaN      NaN
# BeetleFly                                         NaN      NaN
# BirdChicken                                       NaN      NaN
# BME                                               NaN      NaN
# Car                                               NaN      NaN
# CBF                                               NaN      NaN
# Chinatown                                         NaN      NaN
# ...

# %% [markdown]
# ## Catch22 features based classifier

# %%
with open(os.path.join("results", "catch22_results.pkl"), "rb") as f:
    data = pickle.load(f)
data
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py:183: FutureWarning: the 'labels' keyword is deprecated, use 'codes' instead
#   return cls.__new__(cls, **d)
# classifier                     RandomForestClassifier            \
# metric                                       Accuracy  F1-Score
# ACSF1                                        0.830000  0.828355
# Adiac                                        0.708440  0.692048
# ArrowHead                                    0.771429  0.771567
# Beef                                         0.566667  0.569875
# BeetleFly                                    0.800000  0.791667
# BirdChicken                                  0.850000  0.849624
# BME                                          0.913333  0.912979
# Car                                          0.766667  0.770972
# CBF                                          0.951111  0.951028
# Chinatown                                    0.935860  0.924103
# ...

# %% [markdown]
# ## Shapelets-based classifier results

# %%
pd.read_pickle(os.path.join("results", "shapelets_results.pkl"))
# Out:
# classifier                     RandomForestClassifier            \
# metric                                       Accuracy  F1-Score
# ACSF1                                        0.380000  0.387577
# Adiac                                        0.493606  0.477736
# ArrowHead                                    0.714286  0.707066
# Beef                                         0.666667  0.680808
# BeetleFly                                    0.900000  0.898990
# BirdChicken                                  0.900000  0.898990
# BME                                          0.860000  0.858469
# Car                                          0.750000  0.751467
# CBF                                          0.943333  0.943330
# Chinatown                                    0.973761  0.967556
# ChlorineConcentration                        0.447135  0.386044
# CinCECGTorso                                 0.576812  0.588361
# Coffee                                       0.928571  0.927083
# ...

# %% [markdown]
# ## CNN and time series plot based classifier

# %%
with open(os.path.join("results", "cnn_results.pkl"), "rb") as f:
    data = pickle.load(f)
data
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py:183: FutureWarning: the 'labels' keyword is deprecated, use 'codes' instead
#   return cls.__new__(cls, **d)
# classifier         RecurrencePlot           MarkovTransitiveFields            \
# metric                   Accuracy  F1-Score               Accuracy  F1-Score
# ACSF1                    0.100000  0.020408                   0.13  0.056076
# Adiac                    0.063939  0.029896                   0.00  0.000000
# AllGestureWiimoteX       0.075714  0.017608                    NaN       NaN
#
# classifier         GramianAngular
# metric                   Accuracy  F1-Score
# ACSF1                    0.000000  0.000000
# Adiac                    0.053708  0.040408
# AllGestureWiimoteX       0.128571  0.109467
